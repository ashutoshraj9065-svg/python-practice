# %%
pip install numpy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#       --------------------------------------- 0.2/12.9 MB ? eta -:--:--
#      - -------------------------------------- 0.4/12.9 MB 3.5 MB/s eta 0:00:04
#      - -------------------------------------- 0.6/12.9 MB 3.8 MB/s eta 0:00:04
#      --- ------------------------------------ 1.0/12.9 MB 4.7 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.5/12.9 MB 5.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.6/12.9 MB 5.8 MB/s eta 0:00:02
#      ------- -------------------------------- 2.3/12.9 MB 6.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.9 MB 7.3 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.3/12.9 MB 7.8 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.9 MB 7.8 MB/s eta 0:00:02
#      ------------ --------------------------- 4.0/12.9 MB 7.1 MB/s eta 0:00:02
# ...

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.2.6'

# %%
a=np.array([1,2,3,4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b=np.array([1,2,3,4,"5"])

# %%
b
# Out:
# array(['1', '2', '3', '4', '5'], dtype='<U21')

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.dtype
# Out:
# dtype('<U21')

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.shape
# Out:
# (5,)

# %%
a.ndim
# Out:
# 1

# %%
a.itemsize
# Out:
# 8

# %%
a.nbytes
# Out:
# 40

# %%
a.size
# Out:
# 5
