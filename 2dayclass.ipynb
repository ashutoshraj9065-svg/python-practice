# %%
nums = [8, 3, 6, 1, 5]

small=nums[0]

for i in nums:
    if i<small: 
        small=i 
print(small)
# Out:
# 1

# %%
nums = [2, 3, 2, 5, 3, 2] 

count={} 

for i in nums: 
    if i in count:
        count[i]=count[i]+1
    else:
        count[i]=1
print(count)
# Out:
# {2: 3, 3: 2, 5: 1}
