# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

# %%
load_dotenv()
llm=ChatGroq(model="openai/gpt-oss-120b",
            api_key=os.getenv("Groq_key"))

responce=llm.invoke("what is difference between where and haveing in sql only two block point simple langauge")

print(responce.content)
# Out:
# **WHERE**
# - Filters **individual rows** as the data is read from the tables.
# - Works **before** any `GROUP BY`/aggregation, so you can’t use aggregate functions (e.g., `SUM`, `COUNT`) in a `WHERE` clause.
#
# **HAVING**
# - Filters **groups of rows** that are created by `GROUP BY`.
# - Works **after** the aggregation, so you can refer to aggregate results (e.g., `HAVING COUNT(*) > 5`).
